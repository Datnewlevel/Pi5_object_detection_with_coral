# %%
# %env PYTHONPATH = # /env/python

# %%
# !wget -q https://repo.anaconda.com/miniconda/Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py39_23.3.1-0-Linux-x86_64.sh
# !./Miniconda3-py39_23.3.1-0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update -y conda

# %%
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages')

# %%
# !conda create -y -n myenv python=3.9

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
#
# pip install ipykernel
# pip install opencv-python
# pip install pycocotools
#
# pip install tflite-model-maker==0.4.3
# pip install tflite-support
#
# pip install --force-reinstall matplotlib==3.4.3
# pip install --force-reinstall matplotlib-inline==0.1.6
#
# pip install --force-reinstall packaging==20.9
#
# pip install --force-reinstall numpy==1.23.3

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
#
# python -c "
# import numpy; print('numpy:', numpy.__version__)
# import matplotlib; print('matplotlib:', matplotlib.__version__)
# import tensorflow; print('tensorflow:', tensorflow.__version__)
# import tflite_model_maker; print('tflite_model_maker: OK')
# "

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive

# %%
# !unzip -q /mydrive/freedomtech.zip

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# python /content/train.py

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
#
# curl https://packages.cloud.google.com/apt/doc/apt-key.gpg | sudo apt-key add -
# echo "deb https://packages.cloud.google.com/apt coral-edgetpu-stable main" | sudo tee /etc/apt/sources.list.d/coral-edgetpu.list
# sudo apt-get update -q
# sudo apt-get install -y edgetpu-compiler

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# edgetpu_compiler best.tflite

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# python /content/test.py
